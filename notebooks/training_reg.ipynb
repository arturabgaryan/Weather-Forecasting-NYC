# %%
import json
import joblib
import numpy as np
import pandas as pd

from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

from models.regression import train_temperature_model
from models.metrics import regression_metrics

# %%
df = pd.read_csv("../data/processed/regression_data.csv",index_col=0)
df["DATE"] = pd.to_datetime(df["DATE"])
df = df.sort_values("DATE").reset_index(drop=True)
df.tail()
# Out:
#             DATE  TMAX  TMIN  TAVG  PRCP  SNOW   AWND  TMAX_lag_1  \
# 20084 2014-12-27  54.0  37.0  44.0  0.00   0.0   6.26        51.0
# 20085 2014-12-28  54.0  42.0  47.0  0.05   0.0  10.51        54.0
# 20086 2014-12-29  46.0  35.0  43.0  0.00   0.0  10.96        54.0
# 20087 2014-12-30  36.0  28.0  34.0  0.00   0.0   9.40        46.0
# 20088 2014-12-31  34.0  28.0  30.0  0.00   0.0  11.86        36.0
#
#        TMAX_roll_7  dayofyear  month
# 20084    47.857143        361     12
# 20085    50.714286        362     12
# 20086    53.000000        363     12
# 20087    52.714286        364     12
# 20088    50.714286        365     12

# %%
target = "TMAX"

features = [
    "TMIN",
    "PRCP",
    "SNOW",
    "AWND",
    "TMAX_lag_1",
    "TMAX_roll_7",
    "dayofyear",
    "month"
]

df_model = df[features + [target]].dropna()

X = df_model[features]
y = df_model[target]

# %%
test_size = int(len(df_model) * 0.2)

X_train = X.iloc[:-test_size]
X_test  = X.iloc[-test_size:]

y_train = y.iloc[:-test_size]
y_test  = y.iloc[-test_size:]

print("Train size:", X_train.shape)
print("Test size:", X_test.shape)
# Out:
# Train size: (16066, 8)
# Test size: (4016, 8)

# %%
baseline_model = train_temperature_model(
    X_train,
    y_train,
    model_type="linear"
)

baseline_pred = baseline_model.predict(X_test)

baseline_metrics = regression_metrics(y_test,baseline_pred)
baseline_metrics
# Out:
# {'MAE': 3.73174735507421,
#  'RMSE': np.float64(4.764529193089308),
#  'R2': 0.9256156192511199}

# %%
xgb_model = train_temperature_model(
    X_train,
    y_train,
    model_type="xgboost"
)

y_pred = xgb_model.predict(X_test)

xgb_metrics = regression_metrics(y_test, y_pred)

xgb_metrics
# Out:
# [0]	validation_0-rmse:16.77072
# [1]	validation_0-rmse:16.05907
# [2]	validation_0-rmse:15.33472
# [3]	validation_0-rmse:14.65138
# [4]	validation_0-rmse:14.00560
# [5]	validation_0-rmse:13.39743
# [6]	validation_0-rmse:12.82074
# [7]	validation_0-rmse:12.27626
# [8]	validation_0-rmse:11.76068
# [9]	validation_0-rmse:11.30346
# [10]	validation_0-rmse:10.84451
# [11]	validation_0-rmse:10.41266
# [12]	validation_0-rmse:10.03248
# [13]	validation_0-rmse:9.67572
# [14]	validation_0-rmse:9.31119
# [15]	validation_0-rmse:8.96884
# [16]	validation_0-rmse:8.64749
# [17]	validation_0-rmse:8.34874
# [18]	validation_0-rmse:8.08826
# [19]	validation_0-rmse:7.84656
# [20]	validation_0-rmse:7.59727
# [21]	validation_0-rmse:7.36485
# [22]	validation_0-rmse:7.14916
# [23]	validation_0-rmse:6.96484
# [24]	validation_0-rmse:6.79408
# [25]	validation_0-rmse:6.63803
# [26]	validation_0-rmse:6.47352
# [27]	validation_0-rmse:6.31793
# [28]	validation_0-rmse:6.17340
# [29]	validation_0-rmse:6.04152
# [30]	validation_0-rmse:5.91964
# [31]	validation_0-rmse:5.80633
# [32]	validation_0-rmse:5.70235
# [33]	validation_0-rmse:5.60463
# [34]	validation_0-rmse:5.51405
# [35]	validation_0-rmse:5.43204
# [36]	validation_0-rmse:5.35543
# [37]	validation_0-rmse:5.29230
# [38]	validation_0-rmse:5.22697
# [39]	validation_0-rmse:5.16686
# [40]	validation_0-rmse:5.11638
# [41]	validation_0-rmse:5.06564
# [42]	validation_0-rmse:5.01863
# [43]	validation_0-rmse:4.97963
# [44]	validation_0-rmse:4.94458
# [45]	validation_0-rmse:4.90890
# [46]	validation_0-rmse:4.87545
# [47]	validation_0-rmse:4.84492
# [48]	validation_0-rmse:4.81475
# [49]	validation_0-rmse:4.78879
# [50]	validation_0-rmse:4.76569
# [51]	validation_0-rmse:4.74574
# [52]	validation_0-rmse:4.72537
# [53]	validation_0-rmse:4.70633
# [54]	validation_0-rmse:4.68846
# [55]	validation_0-rmse:4.67340
# [56]	validation_0-rmse:4.65905
# [57]	validation_0-rmse:4.64339
# [58]	validation_0-rmse:4.62932
# [59]	validation_0-rmse:4.61859
# [60]	validation_0-rmse:4.60555
# [61]	validation_0-rmse:4.59587
# [62]	validation_0-rmse:4.58517
# [63]	validation_0-rmse:4.57647
# [64]	validation_0-rmse:4.56532
# [65]	validation_0-rmse:4.55747
# [66]	validation_0-rmse:4.54873
# [67]	validation_0-rmse:4.54015
# [68]	validation_0-rmse:4.53419
# [69]	validation_0-rmse:4.52767
# [70]	validation_0-rmse:4.52289
# [71]	validation_0-rmse:4.51702
# [72]	validation_0-rmse:4.51191
# [73]	validation_0-rmse:4.50755
# [74]	validation_0-rmse:4.50313
# [75]	validation_0-rmse:4.49894
# [76]	validation_0-rmse:4.49378
# [77]	validation_0-rmse:4.48988
# [78]	validation_0-rmse:4.48633
# [79]	validation_0-rmse:4.48254
# [80]	validation_0-rmse:4.47918
# [81]	validation_0-rmse:4.47494
# [82]	validation_0-rmse:4.47070
# [83]	validation_0-rmse:4.46796
# [84]	validation_0-rmse:4.46470
# [85]	validation_0-rmse:4.46058
# [86]	validation_0-rmse:4.45756
# [87]	validation_0-rmse:4.45391
# [88]	validation_0-rmse:4.45142
# [89]	validation_0-rmse:4.44855
# [90]	validation_0-rmse:4.44509
# [91]	validation_0-rmse:4.44195
# [92]	validation_0-rmse:4.43929
# [93]	validation_0-rmse:4.43652
# [94]	validation_0-rmse:4.43369
# [95]	validation_0-rmse:4.43158
# [96]	validation_0-rmse:4.42938
# [97]	validation_0-rmse:4.42696
# [98]	validation_0-rmse:4.42470
# [99]	validation_0-rmse:4.42242
# [100]	validation_0-rmse:4.41971
# [101]	validation_0-rmse:4.41769
# [102]	validation_0-rmse:4.41533
# [103]	validation_0-rmse:4.41344
# [104]	validation_0-rmse:4.41198
# [105]	validation_0-rmse:4.41041
# [106]	validation_0-rmse:4.40866
# [107]	validation_0-rmse:4.40620
# [108]	validation_0-rmse:4.40379
# [109]	validation_0-rmse:4.40286
# [110]	validation_0-rmse:4.40049
# [111]	validation_0-rmse:4.39867
# [112]	validation_0-rmse:4.39656
# [113]	validation_0-rmse:4.39408
# [114]	validation_0-rmse:4.39320
# [115]	validation_0-rmse:4.39172
# [116]	validation_0-rmse:4.39063
# [117]	validation_0-rmse:4.38984
# [118]	validation_0-rmse:4.38821
# [119]	validation_0-rmse:4.38478
# c:\Users\ar12a\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:199: UserWarning: [18:08:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "verbose" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [120]	validation_0-rmse:4.38245
# [121]	validation_0-rmse:4.38175
# [122]	validation_0-rmse:4.38004
# [123]	validation_0-rmse:4.37754
# [124]	validation_0-rmse:4.37589
# [125]	validation_0-rmse:4.37387
# [126]	validation_0-rmse:4.37247
# [127]	validation_0-rmse:4.37059
# [128]	validation_0-rmse:4.36973
# [129]	validation_0-rmse:4.36770
# [130]	validation_0-rmse:4.36672
# [131]	validation_0-rmse:4.36461
# [132]	validation_0-rmse:4.36364
# [133]	validation_0-rmse:4.36120
# [134]	validation_0-rmse:4.35937
# [135]	validation_0-rmse:4.35792
# [136]	validation_0-rmse:4.35715
# [137]	validation_0-rmse:4.35619
# [138]	validation_0-rmse:4.35531
# [139]	validation_0-rmse:4.35328
# [140]	validation_0-rmse:4.35193
# [141]	validation_0-rmse:4.35017
# [142]	validation_0-rmse:4.34907
# [143]	validation_0-rmse:4.34819
# [144]	validation_0-rmse:4.34645
# [145]	validation_0-rmse:4.34479
# [146]	validation_0-rmse:4.34364
# [147]	validation_0-rmse:4.34288
# [148]	validation_0-rmse:4.34216
# [149]	validation_0-rmse:4.34018
# [150]	validation_0-rmse:4.33829
# [151]	validation_0-rmse:4.33809
# [152]	validation_0-rmse:4.33678
# [153]	validation_0-rmse:4.33555
# [154]	validation_0-rmse:4.33445
# [155]	validation_0-rmse:4.33352
# [156]	validation_0-rmse:4.33235
# [157]	validation_0-rmse:4.33137
# [158]	validation_0-rmse:4.33025
# [159]	validation_0-rmse:4.32966
# [160]	validation_0-rmse:4.32894
# [161]	validation_0-rmse:4.32766
# [162]	validation_0-rmse:4.32627
# [163]	validation_0-rmse:4.32433
# [164]	validation_0-rmse:4.32267
# [165]	validation_0-rmse:4.32125
# [166]	validation_0-rmse:4.32074
# [167]	validation_0-rmse:4.31998
# [168]	validation_0-rmse:4.31859
# [169]	validation_0-rmse:4.31685
# [170]	validation_0-rmse:4.31548
# [171]	validation_0-rmse:4.31480
# [172]	validation_0-rmse:4.31407
# [173]	validation_0-rmse:4.31354
# [174]	validation_0-rmse:4.31282
# [175]	validation_0-rmse:4.31142
# [176]	validation_0-rmse:4.31046
# [177]	validation_0-rmse:4.30963
# [178]	validation_0-rmse:4.30873
# [179]	validation_0-rmse:4.30783
# [180]	validation_0-rmse:4.30630
# [181]	validation_0-rmse:4.30582
# [182]	validation_0-rmse:4.30492
# [183]	validation_0-rmse:4.30382
# [184]	validation_0-rmse:4.30335
# [185]	validation_0-rmse:4.30137
# [186]	validation_0-rmse:4.29972
# [187]	validation_0-rmse:4.29863
# [188]	validation_0-rmse:4.29758
# [189]	validation_0-rmse:4.29603
# [190]	validation_0-rmse:4.29489
# [191]	validation_0-rmse:4.29374
# [192]	validation_0-rmse:4.29207
# [193]	validation_0-rmse:4.29116
# [194]	validation_0-rmse:4.28990
# [195]	validation_0-rmse:4.28896
# [196]	validation_0-rmse:4.28720
# [197]	validation_0-rmse:4.28615
# [198]	validation_0-rmse:4.28493
# [199]	validation_0-rmse:4.28336
# [200]	validation_0-rmse:4.28224
# [201]	validation_0-rmse:4.28074
# [202]	validation_0-rmse:4.27877
# [203]	validation_0-rmse:4.27776
# [204]	validation_0-rmse:4.27625
# [205]	validation_0-rmse:4.27522
# [206]	validation_0-rmse:4.27399
# [207]	validation_0-rmse:4.27293
# [208]	validation_0-rmse:4.27154
# [209]	validation_0-rmse:4.27126
# [210]	validation_0-rmse:4.27036
# [211]	validation_0-rmse:4.26893
# [212]	validation_0-rmse:4.26817
# [213]	validation_0-rmse:4.26741
# [214]	validation_0-rmse:4.26662
# [215]	validation_0-rmse:4.26466
# [216]	validation_0-rmse:4.26414
# [217]	validation_0-rmse:4.26356
# [218]	validation_0-rmse:4.26301
# [219]	validation_0-rmse:4.26157
# [220]	validation_0-rmse:4.26047
# [221]	validation_0-rmse:4.25887
# [222]	validation_0-rmse:4.25705
# [223]	validation_0-rmse:4.25601
# [224]	validation_0-rmse:4.25553
# [225]	validation_0-rmse:4.25467
# [226]	validation_0-rmse:4.25377
# [227]	validation_0-rmse:4.25247
# [228]	validation_0-rmse:4.25124
# [229]	validation_0-rmse:4.24989
# [230]	validation_0-rmse:4.24893
# [231]	validation_0-rmse:4.24739
# [232]	validation_0-rmse:4.24657
# [233]	validation_0-rmse:4.24550
# [234]	validation_0-rmse:4.24420
# [235]	validation_0-rmse:4.24362
# [236]	validation_0-rmse:4.24271
# [237]	validation_0-rmse:4.24123
# [238]	validation_0-rmse:4.23972
# [239]	validation_0-rmse:4.23906
# [240]	validation_0-rmse:4.23824
# [241]	validation_0-rmse:4.23646
# [242]	validation_0-rmse:4.23512
# [243]	validation_0-rmse:4.23402
# [244]	validation_0-rmse:4.23227
# [245]	validation_0-rmse:4.23128
# [246]	validation_0-rmse:4.23082
# [247]	validation_0-rmse:4.23029
# [248]	validation_0-rmse:4.22941
# [249]	validation_0-rmse:4.22883
# [250]	validation_0-rmse:4.22791
# [251]	validation_0-rmse:4.22694
# [252]	validation_0-rmse:4.22597
# [253]	validation_0-rmse:4.22507
# [254]	validation_0-rmse:4.22414
# [255]	validation_0-rmse:4.22373
# [256]	validation_0-rmse:4.22281
# [257]	validation_0-rmse:4.22168
# [258]	validation_0-rmse:4.22054
# [259]	validation_0-rmse:4.21951
# [260]	validation_0-rmse:4.21829
# [261]	validation_0-rmse:4.21676
# [262]	validation_0-rmse:4.21600
# [263]	validation_0-rmse:4.21525
# [264]	validation_0-rmse:4.21418
# [265]	validation_0-rmse:4.21313
# [266]	validation_0-rmse:4.21272
# [267]	validation_0-rmse:4.21175
# [268]	validation_0-rmse:4.21052
# [269]	validation_0-rmse:4.20896
# [270]	validation_0-rmse:4.20830
# [271]	validation_0-rmse:4.20704
# [272]	validation_0-rmse:4.20556
# [273]	validation_0-rmse:4.20474
# [274]	validation_0-rmse:4.20413
# [275]	validation_0-rmse:4.20208
# [276]	validation_0-rmse:4.20098
# [277]	validation_0-rmse:4.20012
# [278]	validation_0-rmse:4.19934
# [279]	validation_0-rmse:4.19780
# [280]	validation_0-rmse:4.19725
# [281]	validation_0-rmse:4.19645
# [282]	validation_0-rmse:4.19526
# [283]	validation_0-rmse:4.19378
# [284]	validation_0-rmse:4.19300
# [285]	validation_0-rmse:4.19249
# [286]	validation_0-rmse:4.19043
# [287]	validation_0-rmse:4.18965
# [288]	validation_0-rmse:4.18873
# [289]	validation_0-rmse:4.18726
# [290]	validation_0-rmse:4.18618
# [291]	validation_0-rmse:4.18530
# [292]	validation_0-rmse:4.18427
# [293]	validation_0-rmse:4.18364
# [294]	validation_0-rmse:4.18242
# [295]	validation_0-rmse:4.18066
# [296]	validation_0-rmse:4.17968
# [297]	validation_0-rmse:4.17913
# [298]	validation_0-rmse:4.17817
# [299]	validation_0-rmse:4.17712
# {'MAE': 3.4392292000857956,
#  'RMSE': np.float64(4.431217270226271),
#  'R2': 0.9356589925491391}

# %%
pd.DataFrame(
    [baseline_metrics, xgb_metrics],
    index=["Baseline (Linear)", "XGBoosting"]
)
# Out:
#                         MAE      RMSE        R2
# Baseline (Linear)  3.731747  4.764529  0.925616
# XGBoosting         3.439229  4.431217  0.935659

# %%
joblib.dump(xgb_model, "../models/artifacts/models/tmax_xgboost.joblib")

with open("../models/artifacts/metrics/regression_metrics.json", "w") as f:
    json.dump(xgb_metrics, f, indent=2)

with open("../models/artifacts/params/xgboost_params.json", "w") as f:
    json.dump(xgb_model.get_params(), f, indent=2)

feature_config = {
    "target": "TMAX",
    "features": [
        "TMIN",
        "PRCP",
        "SNOW",
        "AWND",
        "TMAX_lag_1",
        "TMAX_roll_7",
        "monthly_avg_TMAX",
        "dayofyear",
        "month"
    ]
}

with open("../models/artifacts/metadata/xgboost_info.json", "w") as f:
    json.dump(feature_config, f, indent=2)
